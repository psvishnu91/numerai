# %% [markdown]
# ## Notebook to try sequential feature selection
#
# ### Approach
# #### Setup
# 1. Take each of the 3CV x 36-target model predictions for each of the 3 CV `test` sets.
# 2. Split the 3 CV test sets into 3 `validation` (120 eras) and 3 `test` sets (120 eras).
# 3. The validation eras are further split into `val1` and `val2` 60 eras each.
#
# #### Sequential feature selection
# 1. We start with the cyrus only prediction.
# 2. Then we perform regress 35 regressions where we pairwise regress cyrus+ each of the 35 other targets individually on `val1` (60 eras).
# 3. We then rank them based on their performance on `val2` and select the best.
# 4. In the next round we add predictions from the next best target amongst 34 options and continue.
#
# ### Observations
# The performance on `val2` improved with each addition, the performance on test plummeted as we overfit easily. Abandoned the approach.
#
# ### Next steps and revisiting
# If revisiting the next time, we should not split validation into `val1` and `val2` but simply regress on the entire `validation` set and select features based on in-sample performance perhaps? That way we at least have 120 eras to regress over instead of 60.

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))

from importlib import reload
import logging
reload(logging)
import logging
logging.basicConfig(level=logging.INFO)

import glob
import numpy as np
import datetime
import json
import os
import os.path
from os.path import join
import warnings
import flatdict
import pandas as pd
import mlflow
import gc
import plotly.graph_objects as go
import functools
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.offline as pyo
import itertools as it
from typing import List
import time
import copy

import utils as ut

from pprint import pprint, pformat
from tqdm.notebook import tqdm

from utils import ERA_COL, TARGET_COL


pyo.init_notebook_mode()
pd.options.mode.chained_assignment = None  # default='warn'
# Filter the setuptools UserWarning until we stop relying on distutils
warnings.filterwarnings("ignore")
DF = pd.DataFrame
sns.set_theme()
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 1. Constants

# %%
LOCAL = False
if LOCAL:
    ML_TRACKING_SERVER_URI = "http://127.0.0.1:5000"
    AWS_CREDENTIALS_FILE = "~/.aws/personal_credentials"
else:
    ML_TRACKING_SERVER_URI = "http://18.218.213.146:5500/"
    AWS_CREDENTIALS_FILE = "~/.aws/credentials"
EXPERIMENT_NAME = f"ensemble_tgts_for_cyrus_2023-04-26_19h-36m"
DATA_PATH = "./data/"
VAL_PRED_S3_PATH = (
    "s3://numerai-v1/experiments/"
    "ensemble_tgts_for_cyrus_2023-04-26_19h-36m/"
    "ckpt1_cv_val_preds_no_feats.pkl"
)
ENSEMBLE_MODELS_S3_PATH = (
    "s3://numerai-v1/experiments/"
    "ensemble_tgts_for_cyrus_2023-04-26_19h-36m/"
    "ensemble_models/"
)

log = ut.Logger(root_dir="./")

EXPT_LOCAL_DIR = os.path.join(DATA_PATH, "experiments", EXPERIMENT_NAME)
MODEL_DIR = join(EXPT_LOCAL_DIR, "models")
for fld in [EXPT_LOCAL_DIR, MODEL_DIR]:
    os.makedirs(fld, exist_ok=True)
    log.info(f"Making {fld}")
    
log.info(f"{EXPERIMENT_NAME=}")
log.info(f"{VAL_PRED_S3_PATH=}")
# Out:
# [2023-04-28 19:46:25]  Making ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m
# [2023-04-28 19:46:25]  Making ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models
# [2023-04-28 19:46:25]  EXPERIMENT_NAME='ensemble_tgts_for_cyrus_2023-04-26_19h-36m'
# [2023-04-28 19:46:25]  VAL_PRED_S3_PATH='s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ckpt1_cv_val_preds_no_feats.pkl'

# %%
log.info(f"{TARGET_COL=}")
# Out:
# [2023-04-28 19:46:26]  TARGET_COL='target_cyrus_v4_20'

# %% [markdown]
# ## 2. Download data and load up the model predns on val data

# %%
# mlflow.set_tracking_uri(ML_TRACKING_SERVER_URI)
# try:
#     cv_expt_id = mlflow.create_experiment(name=EXPERIMENT_NAME)
# except Exception:
#     cv_expt_id = mlflow.get_experiment_by_name(name=EXPERIMENT_NAME).experiment_id
# log.info(f"{EXPERIMENT_NAME=}, {cv_expt_id=}")

# %%
ut.download_s3_file(
    local_path=EXPT_LOCAL_DIR,
    s3_path=VAL_PRED_S3_PATH,
    aws_credential_fl=AWS_CREDENTIALS_FILE,
)
# Out:
# [2023-04-28 19:46:29]  Loading aws credenitals from ~/.aws/credentials...
# [2023-04-28 19:46:29]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ckpt1_cv_val_preds_no_feats.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ckpt1_cv_val_preds_no_feats.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ckpt1_cv_val_preds_no_feats.pkl exists. Will not download again ...

# %%
cv_valpreds_orig = ut.unpickle_obj(fl=join(EXPT_LOCAL_DIR, "ckpt1_cv_val_preds_no_feats.pkl"))

# %%
# HACK: Accidentally duplicated the columns twice, only include them once instead
NUM_TARGETS = 36
cv_valpreds = copy.deepcopy(cv_valpreds_orig)
cv_valpreds["cv_predcols_map"] = [
    cv_pc[:NUM_TARGETS]
    for cv_pc in cv_valpreds["cv_predcols_map"]
]

# %%
gc.collect()
# Out:
# 23810

# %%
split = 0
cv_valpreds["cv_to_val_test_map"][split]["val"].head()
# Out:
#                   target  target_nomi_v4_20  target_nomi_v4_60  \
# id
# n001f768affa1cc2     1.0                1.0               0.75
# n002cc5b29f8705f     0.5                0.5               0.50
# n00361f031876c68     0.5                0.5               0.50
# n00385e672d049e6     0.0                0.0               0.25
# n00503d13b28d441     0.5                0.5               0.50
#
#                   target_tyler_v4_20  target_tyler_v4_60  target_victor_v4_20  \
# id
# n001f768affa1cc2                0.75                0.75                  1.0
# n002cc5b29f8705f                0.25                0.50                  0.5
# n00361f031876c68                0.50                0.50                  0.5
# n00385e672d049e6                0.25                0.50                  0.0
# n00503d13b28d441                0.50                0.25                  0.5
#
#                   target_victor_v4_60  target_ralph_v4_20  target_ralph_v4_60  \
# id
# n001f768affa1cc2                 0.75                 1.0                0.75
# n002cc5b29f8705f                 0.50                 0.5                0.50
# n00361f031876c68                 0.50                 0.5                0.50
# n00385e672d049e6                 0.25                 0.0                0.25
# n00503d13b28d441                 0.50                 0.5                0.50
#
#                   target_waldo_v4_20  ...  pred_target_ben_v4_20_cv0  \
# id                                    ...
# n001f768affa1cc2                 1.0  ...                   0.493943
# n002cc5b29f8705f                 0.5  ...                   0.495377
# n00361f031876c68                 0.5  ...                   0.488254
# n00385e672d049e6                 0.0  ...                   0.491807
# n00503d13b28d441                 0.5  ...                   0.524468
#
#                   pred_target_ben_v4_60_cv0  pred_target_alan_v4_20_cv0  \
# id
# n001f768affa1cc2                   0.475514                    0.494528
# n002cc5b29f8705f                   0.509305                    0.496175
# n00361f031876c68                   0.486235                    0.493248
# n00385e672d049e6                   0.488826                    0.511420
# n00503d13b28d441                   0.498629                    0.533116
#
#                   pred_target_alan_v4_60_cv0  pred_target_paul_v4_20_cv0  \
# id
# n001f768affa1cc2                    0.478933                    0.454020
# n002cc5b29f8705f                    0.490550                    0.474163
# n00361f031876c68                    0.480340                    0.482077
# n00385e672d049e6                    0.501787                    0.455790
# n00503d13b28d441                    0.521875                    0.532201
#
#                   pred_target_paul_v4_60_cv0  pred_target_george_v4_20_cv0  \
# id
# n001f768affa1cc2                    0.450485                      0.455395
# n002cc5b29f8705f                    0.483902                      0.486066
# n00361f031876c68                    0.454602                      0.475474
# n00385e672d049e6                    0.444844                      0.475221
# n00503d13b28d441                    0.516652                      0.525540
#
#                   pred_target_george_v4_60_cv0  pred_target_william_v4_20_cv0  \
# id
# n001f768affa1cc2                      0.436630                       0.499045
# n002cc5b29f8705f                      0.495735                       0.498365
# n00361f031876c68                      0.466946                       0.485363
# n00385e672d049e6                      0.449966                       0.494380
# n00503d13b28d441                      0.507236                       0.533293
#
#                   pred_target_william_v4_60_cv0
# id
# n001f768affa1cc2                       0.476133
# n002cc5b29f8705f                       0.507437
# n00361f031876c68                       0.479478
# n00385e672d049e6                       0.498582
# n00503d13b28d441                       0.513035
#
# [5 rows x 75 columns]

# %%
cv_valpreds["cv_to_val_test_map"][split]["test"].head()
# Out:
#                   target  target_nomi_v4_20  target_nomi_v4_60  \
# id
# n00164cb9c597154    1.00               1.00               0.50
# n0028609fde88b03    1.00               1.00               0.75
# n002bfff507f118e    0.50               0.50               0.50
# n002d0d989a01142    0.75               0.75               0.50
# n00620b3b0a59ab1    0.75               0.75               0.50
#
#                   target_tyler_v4_20  target_tyler_v4_60  target_victor_v4_20  \
# id
# n00164cb9c597154                0.75                0.50                 1.00
# n0028609fde88b03                0.75                0.50                 0.75
# n002bfff507f118e                0.50                0.25                 0.50
# n002d0d989a01142                0.75                0.50                 0.75
# n00620b3b0a59ab1                1.00                0.50                 0.75
#
#                   target_victor_v4_60  target_ralph_v4_20  target_ralph_v4_60  \
# id
# n00164cb9c597154                  0.5                1.00                 0.5
# n0028609fde88b03                  0.5                0.75                 0.5
# n002bfff507f118e                  0.5                0.25                 0.5
# n002d0d989a01142                  0.5                0.75                 0.5
# n00620b3b0a59ab1                  0.5                0.50                 0.5
#
#                   target_waldo_v4_20  ...  pred_target_ben_v4_20_cv0  \
# id                                    ...
# n00164cb9c597154                0.75  ...                   0.462140
# n0028609fde88b03                1.00  ...                   0.525290
# n002bfff507f118e                0.25  ...                   0.496298
# n002d0d989a01142                0.75  ...                   0.501930
# n00620b3b0a59ab1                0.75  ...                   0.479739
#
#                   pred_target_ben_v4_60_cv0  pred_target_alan_v4_20_cv0  \
# id
# n00164cb9c597154                   0.453088                    0.488272
# n0028609fde88b03                   0.538764                    0.500456
# n002bfff507f118e                   0.508979                    0.501143
# n002d0d989a01142                   0.506025                    0.514477
# n00620b3b0a59ab1                   0.485134                    0.504286
#
#                   pred_target_alan_v4_60_cv0  pred_target_paul_v4_20_cv0  \
# id
# n00164cb9c597154                    0.476812                    0.432102
# n0028609fde88b03                    0.505370                    0.526002
# n002bfff507f118e                    0.494654                    0.529000
# n002d0d989a01142                    0.505899                    0.552279
# n00620b3b0a59ab1                    0.501196                    0.535674
#
#                   pred_target_paul_v4_60_cv0  pred_target_george_v4_20_cv0  \
# id
# n00164cb9c597154                    0.393445                      0.457779
# n0028609fde88b03                    0.543837                      0.532270
# n002bfff507f118e                    0.535165                      0.514607
# n002d0d989a01142                    0.565865                      0.508856
# n00620b3b0a59ab1                    0.544112                      0.506822
#
#                   pred_target_george_v4_60_cv0  pred_target_william_v4_20_cv0  \
# id
# n00164cb9c597154                      0.419536                       0.475697
# n0028609fde88b03                      0.560145                       0.518491
# n002bfff507f118e                      0.524918                       0.508741
# n002d0d989a01142                      0.536651                       0.522526
# n00620b3b0a59ab1                      0.511838                       0.491546
#
#                   pred_target_william_v4_60_cv0
# id
# n00164cb9c597154                       0.458260
# n0028609fde88b03                       0.522983
# n002bfff507f118e                       0.520494
# n002d0d989a01142                       0.516137
# n00620b3b0a59ab1                       0.476516
#
# [5 rows x 75 columns]

# %% [markdown]
# ### 2.1 Download the previously trained ensemble models

# %%
ut.download_from_s3_recursively(
    local_path=MODEL_DIR,
    s3_path=ENSEMBLE_MODELS_S3_PATH,
    aws_credential_fl=AWS_CREDENTIALS_FILE,
)
# Out:
# [2023-04-28 19:46:35]  Loading aws credenitals from ~/.aws/credentials...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.001_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.001_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.001_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.001_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.001_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.001_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.001_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.001_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.001_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.01_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.01_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.01_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.01_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.01_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.01_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.01_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.01_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.01_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.15_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.15_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.15_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.15_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.15_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.15_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.15_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.15_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.15_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.1_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.1_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.1_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.1_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.1_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.1_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.1_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.1_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.1_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.2_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.2_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.2_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.2_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.2_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.2_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.2_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.2_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.2_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.4_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.4_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.4_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.4_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.4_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.4_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.4_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.4_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.4_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6000000000000001_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.6_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.6_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.6_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.6_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.8_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.8_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.8_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.8_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.8_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.8_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_0.8_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.8_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_0.8_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_1.0_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_1.0_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_1.0_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_1.0_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_1.0_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_1.0_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.0001_l1_ratio_1.0_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_1.0_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.0001_l1_ratio_1.0_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.4_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.4_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.4_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.4_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.4_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.4_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.4_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.4_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.4_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.6_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.6_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.6_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.6_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.6_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.6_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.6_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.6_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.6_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.8_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.8_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.8_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.8_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.8_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.8_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_0.8_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.8_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_0.8_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_1.0_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_1.0_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_1.0_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_1.0_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_1.0_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_1.0_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_0.001_l1_ratio_1.0_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_1.0_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_0.001_l1_ratio_1.0_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.001_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.001_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.001_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.001_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.001_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.001_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.001_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.001_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.001_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.01_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.01_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.01_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.01_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.01_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.01_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.01_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.01_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.01_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.15_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.15_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.15_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.15_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.15_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.15_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.15_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.15_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.15_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.1_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.1_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.1_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.1_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.1_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.1_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.1_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.1_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.1_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.2_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.2_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.2_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.2_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.2_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.2_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.2_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.2_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.2_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.4_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.4_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.4_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.4_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.4_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.4_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.4_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.4_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.4_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6000000000000001_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.6_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.6_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.6_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.6_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.8_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.8_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.8_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.8_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.8_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.8_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_0.8_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.8_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_0.8_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_1.0_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_1.0_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_1.0_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_1.0_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_1.0_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_1.0_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-05_l1_ratio_1.0_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_1.0_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-05_l1_ratio_1.0_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.001_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.001_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.001_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.001_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.001_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.001_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.001_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.001_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.001_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.01_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.01_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.01_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.01_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.01_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.01_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.01_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.01_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.01_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.15_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.15_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.15_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.15_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.15_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.15_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.15_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.15_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.15_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.1_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.1_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.1_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.1_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.1_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.1_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.1_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.1_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.1_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.2_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.2_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.2_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.2_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.2_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.2_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.2_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.2_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.2_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.4_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.4_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.4_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.4_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.4_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.4_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.4_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.4_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.4_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6000000000000001_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.6_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.6_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.6_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.6_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.8_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.8_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.8_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.8_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.8_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.8_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_0.8_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.8_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_0.8_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_1.0_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_1.0_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_1.0_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_1.0_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_1.0_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_1.0_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-06_l1_ratio_1.0_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_1.0_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-06_l1_ratio_1.0_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-07_l1_ratio_0.2_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.2_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.2_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-07_l1_ratio_0.2_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.2_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.2_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-07_l1_ratio_0.2_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.2_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.2_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-07_l1_ratio_0.4_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.4_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.4_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-07_l1_ratio_0.4_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.4_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.4_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:36]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/en__alpha_1e-07_l1_ratio_0.4_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.4_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/en__alpha_1e-07_l1_ratio_0.4_cv2.pkl.pkl exists. Will not download again ...
# ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_20_ridge_alpha_10_noint_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.0_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.1_noint_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.3_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_0.6_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_1.0_noint_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_cv2.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv0.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv0.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv0.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv1.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv1.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv1.pkl.pkl exists. Will not download again ...
# [2023-04-28 19:46:37]  Would have downloaded s3://numerai-v1/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/ensemble_models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv2.pkl.pkl to ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv2.pkl.pkl. But ./data/experiments/ensemble_tgts_for_cyrus_2023-04-26_19h-36m/models/pair_pred_target_xerxes_v4_60_ridge_alpha_10_noint_cv2.pkl.pkl exists. Will not download again ...

# %% [markdown]
# ## 3. Compute baseline metrics which is simply taking the average

# %%
def extract_cols_like(all_cols, match_cols):
    return [
        col for col in all_cols
        if any(partial in col for partial in match_cols)
    ]

# %%
import re
def refmt_predcols(col):
    """Use regex to extract col name 
    pred_target_arthur_v4_20_cv1 -> pred_arthur_v4_20"""
    return re.search(r"pred_target_(\w+)_cv", col).group(1)

# %%
def score_baselines(
    cv_valpreds,
    predcols_subset=None,
    agg_fn=np.mean,
    baseline_name="",
):
    """
    :param predcols_subset: This could be a partial name like ['arthur_v4_20', 'nomi_v4_60']
    """
    cv = len(cv_valpreds["cv_predcols_map"])
    # xval metrics, xval ensemble columns, xval prediction value describe
    bl_cv_metrics, bl_cv_predcols, cv_pred_descs = [], [], []
    for split, predcols, val_test_map in tqdm(
        zip(
            range(cv),
            cv_valpreds["cv_predcols_map"],
            cv_valpreds["cv_to_val_test_map"],
        ),
        desc="CV split",
        total=cv,
    ):
        train_df, test_df = val_test_map["val"], val_test_map["test"]
        log.info(
            f"{split=}, {train_df[predcols].shape=}, {train_df.era.min()=}, "
            f"{train_df.era.max()=}, {train_df.era.nunique()=}",
        )
        log.info(
            f"{split=}, {test_df[predcols].shape=}, {test_df.era.min()=}, "
            f"{test_df.era.max()=}, {test_df.era.nunique()=}",
        )
        ensmbl_predcol = f"ensemble_{baseline_name}_cv{split}"
        if predcols_subset is None:
            chosen_fts = predcols
        else:
            chosen_fts = extract_cols_like(all_cols=predcols, match_cols=predcols_subset)
        log.info(f"Chosen {len(chosen_fts)} features: \n{chosen_fts}")
        test_df[ensmbl_predcol] = agg_fn(test_df[chosen_fts], axis=1)
        bl_cv_metrics.append(
            ut.validation_metrics(
                validation_data=test_df, pred_cols=[ensmbl_predcol], target_col=TARGET_COL
            ),
        )
        cv_pred_descs.append(test_df[ensmbl_predcol].describe())
    log.info("Prediction distribution")
    display(pd.concat(cv_pred_descs, axis=1))
    baseline_metrics = ut.to_cv_agg_df(bl_cv_metrics)
    display(ut.fmt_metrics_df(baseline_metrics))
    return baseline_metrics

# %% [markdown]
# ### 3.1 Average all 36 target models

# %%
bl_allpred_mean_metrics = score_baselines(
    cv_valpreds=cv_valpreds,
    predcols_subset=None,
    agg_fn=np.mean,
    baseline_name="allpreds_mean",
)
# Out:
# CV split:   0%|          | 0/3 [00:00<?, ?it/s]
# [2023-04-28 19:46:39]  split=0, train_df[predcols].shape=(587086, 36), train_df.era.min()=820, train_df.era.max()=935, train_df.era.nunique()=116
# [2023-04-28 19:46:39]  split=0, test_df[predcols].shape=(590333, 36), test_df.era.min()=948, test_df.era.max()=1059, test_df.era.nunique()=112
# [2023-04-28 19:46:39]  Chosen 36 features:
# ['pred_target_arthur_v4_20_cv0', 'pred_target_arthur_v4_60_cv0', 'pred_target_thomas_v4_20_cv0', 'pred_target_thomas_v4_60_cv0', 'pred_target_cyrus_v4_20_cv0', 'pred_target_cyrus_v4_60_cv0', 'pred_target_caroline_v4_20_cv0', 'pred_target_caroline_v4_60_cv0', 'pred_target_sam_v4_20_cv0', 'pred_target_sam_v4_60_cv0', 'pred_target_xerxes_v4_20_cv0', 'pred_target_xerxes_v4_60_cv0', 'pred_target_nomi_v4_20_cv0', 'pred_target_nomi_v4_60_cv0', 'pred_target_tyler_v4_20_cv0', 'pred_target_tyler_v4_60_cv0', 'pred_target_victor_v4_20_cv0', 'pred_target_victor_v4_60_cv0', 'pred_target_ralph_v4_20_cv0', 'pred_target_ralph_v4_60_cv0', 'pred_target_waldo_v4_20_cv0', 'pred_target_waldo_v4_60_cv0', 'pred_target_jerome_v4_20_cv0', 'pred_target_jerome_v4_60_cv0', 'pred_target_janet_v4_20_cv0', 'pred_target_janet_v4_60_cv0', 'pred_target_ben_v4_20_cv0', 'pred_target_ben_v4_60_cv0', 'pred_target_alan_v4_20_cv0', 'pred_target_alan_v4_60_cv0', 'pred_target_paul_v4_20_cv0', 'pred_target_paul_v4_60_cv0', 'pred_target_george_v4_20_cv0', 'pred_target_george_v4_60_cv0', 'pred_target_william_v4_20_cv0', 'pred_target_william_v4_60_cv0']
# [2023-04-28 19:46:39]  split=1, train_df[predcols].shape=(571392, 36), train_df.era.min()=556, train_df.era.max()=671, train_df.era.nunique()=116
# [2023-04-28 19:46:39]  split=1, test_df[predcols].shape=(571414, 36), test_df.era.min()=684, test_df.era.max()=795, test_df.era.nunique()=112
# [2023-04-28 19:46:39]  Chosen 36 features:
# ['pred_target_arthur_v4_20_cv1', 'pred_target_arthur_v4_60_cv1', 'pred_target_thomas_v4_20_cv1', 'pred_target_thomas_v4_60_cv1', 'pred_target_cyrus_v4_20_cv1', 'pred_target_cyrus_v4_60_cv1', 'pred_target_caroline_v4_20_cv1', 'pred_target_caroline_v4_60_cv1', 'pred_target_sam_v4_20_cv1', 'pred_target_sam_v4_60_cv1', 'pred_target_xerxes_v4_20_cv1', 'pred_target_xerxes_v4_60_cv1', 'pred_target_nomi_v4_20_cv1', 'pred_target_nomi_v4_60_cv1', 'pred_target_tyler_v4_20_cv1', 'pred_target_tyler_v4_60_cv1', 'pred_target_victor_v4_20_cv1', 'pred_target_victor_v4_60_cv1', 'pred_target_ralph_v4_20_cv1', 'pred_target_ralph_v4_60_cv1', 'pred_target_waldo_v4_20_cv1', 'pred_target_waldo_v4_60_cv1', 'pred_target_jerome_v4_20_cv1', 'pred_target_jerome_v4_60_cv1', 'pred_target_janet_v4_20_cv1', 'pred_target_janet_v4_60_cv1', 'pred_target_ben_v4_20_cv1', 'pred_target_ben_v4_60_cv1', 'pred_target_alan_v4_20_cv1', 'pred_target_alan_v4_60_cv1', 'pred_target_paul_v4_20_cv1', 'pred_target_paul_v4_60_cv1', 'pred_target_george_v4_20_cv1', 'pred_target_george_v4_60_cv1', 'pred_target_william_v4_20_cv1', 'pred_target_william_v4_60_cv1']
# [2023-04-28 19:46:40]  split=2, train_df[predcols].shape=(500976, 36), train_df.era.min()=292, train_df.era.max()=408, train_df.era.nunique()=117
# [2023-04-28 19:46:40]  split=2, test_df[predcols].shape=(507469, 36), test_df.era.min()=421, test_df.era.max()=531, test_df.era.nunique()=111
# [2023-04-28 19:46:40]  Chosen 36 features:
# ['pred_target_arthur_v4_20_cv2', 'pred_target_arthur_v4_60_cv2', 'pred_target_thomas_v4_20_cv2', 'pred_target_thomas_v4_60_cv2', 'pred_target_cyrus_v4_20_cv2', 'pred_target_cyrus_v4_60_cv2', 'pred_target_caroline_v4_20_cv2', 'pred_target_caroline_v4_60_cv2', 'pred_target_sam_v4_20_cv2', 'pred_target_sam_v4_60_cv2', 'pred_target_xerxes_v4_20_cv2', 'pred_target_xerxes_v4_60_cv2', 'pred_target_nomi_v4_20_cv2', 'pred_target_nomi_v4_60_cv2', 'pred_target_tyler_v4_20_cv2', 'pred_target_tyler_v4_60_cv2', 'pred_target_victor_v4_20_cv2', 'pred_target_victor_v4_60_cv2', 'pred_target_ralph_v4_20_cv2', 'pred_target_ralph_v4_60_cv2', 'pred_target_waldo_v4_20_cv2', 'pred_target_waldo_v4_60_cv2', 'pred_target_jerome_v4_20_cv2', 'pred_target_jerome_v4_60_cv2', 'pred_target_janet_v4_20_cv2', 'pred_target_janet_v4_60_cv2', 'pred_target_ben_v4_20_cv2', 'pred_target_ben_v4_60_cv2', 'pred_target_alan_v4_20_cv2', 'pred_target_alan_v4_60_cv2', 'pred_target_paul_v4_20_cv2', 'pred_target_paul_v4_60_cv2', 'pred_target_george_v4_20_cv2', 'pred_target_george_v4_60_cv2', 'pred_target_william_v4_20_cv2', 'pred_target_william_v4_60_cv2']
# [2023-04-28 19:46:41]  Prediction distribution
#        ensemble_allpreds_mean_cv0  ensemble_allpreds_mean_cv1  \
# count               590333.000000               571414.000000
# mean                     0.499084                    0.501019
# std                      0.016239                    0.018883
# min                      0.403835                    0.392828
# 25%                      0.488993                    0.488816
# 50%                      0.499610                    0.501000
# 75%                      0.509779                    0.513161
# max                      0.573454                    0.602210
#
#        ensemble_allpreds_mean_cv2
# count               507469.000000
# mean                     0.499891
# std                      0.025984
# min                      0.361744
# 25%                      0.483469
# 50%                      0.499875
# 75%                      0.516336
# max                      0.649094
# <style type="text/css">
# #T_aee36   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_aee36 thead {
#   background-color: lightblue;
# }
# #T_aee36 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_aee36 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_aee36 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_aee36 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_aee36_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.7%, transparent 94.7%);
# }
# #T_aee36_row0_col1, #T_aee36_row5_col0, #T_aee36_row5_col1, #T_aee36_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_aee36_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.5%, transparent 86.5%);
# }
# #T_aee36_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.6%, transparent 99.6%);
# }
# #T_aee36_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.2%, transparent 93.2%);
# }
# #T_aee36_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 96.8%, transparent 96.8%);
# }
# #T_aee36_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.4%, transparent 97.4%);
# }
# #T_aee36_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 91.4%, transparent 91.4%);
# }
# #T_aee36_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 96.6%, transparent 96.6%);
# }
# #T_aee36_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.2%, transparent 97.2%);
# }
# #T_aee36_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.9%, transparent 94.9%);
# }
# #T_aee36_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.3%, transparent 93.3%);
# }
# #T_aee36_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.5%, transparent 94.5%);
# }
# #T_aee36_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 89.7%, transparent 89.7%);
# }
# #T_aee36_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.6%, transparent 86.6%);
# }
# #T_aee36_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 52.4%, transparent 52.4%);
# }
# #T_aee36_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 54.5%, transparent 54.5%);
# }
# #T_aee36_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 55.9%, transparent 55.9%);
# }
# </style>
# <table id="T_aee36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aee36_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_aee36_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_aee36_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aee36_level0_row0" class="row_heading level0 row0" >ensemble_allpreds_mean_cv0</th>
#       <td id="T_aee36_row0_col0" class="data row0 col0" >2.56%</td>
#       <td id="T_aee36_row0_col1" class="data row0 col1" >2.14%</td>
#       <td id="T_aee36_row0_col2" class="data row0 col2" >119.57%</td>
#     </tr>
#     <tr>
#       <th id="T_aee36_level0_row1" class="row_heading level0 row1" >ensemble_allpreds_mean_cv1</th>
#       <td id="T_aee36_row1_col0" class="data row1 col0" >2.84%</td>
#       <td id="T_aee36_row1_col1" class="data row1 col1" >1.85%</td>
#       <td id="T_aee36_row1_col2" class="data row1 col2" >153.61%</td>
#     </tr>
#     <tr>
#       <th id="T_aee36_level0_row2" class="row_heading level0 row2" >ensemble_allpreds_mean_cv2</th>
#       <td id="T_aee36_row2_col0" class="data row2 col0" >2.71%</td>
#       <td id="T_aee36_row2_col1" class="data row2 col1" >1.78%</td>
#       <td id="T_aee36_row2_col2" class="data row2 col2" >152.79%</td>
#     </tr>
#     <tr>
#       <th id="T_aee36_level0_row3" class="row_heading level0 row3" >cv_mean</th>
#       <td id="T_aee36_row3_col0" class="data row3 col0" >2.71%</td>
#       <td id="T_aee36_row3_col1" class="data row3 col1" >1.92%</td>
#       <td id="T_aee36_row3_col2" class="data row3 col2" >141.99%</td>
#     </tr>
#     <tr>
#       <th id="T_aee36_level0_row4" class="row_heading level0 row4" >cv_low</th>
#       <td id="T_aee36_row4_col0" class="data row4 col0" >2.55%</td>
#       <td id="T_aee36_row4_col1" class="data row4 col1" >1.70%</td>
#       <td id="T_aee36_row4_col2" class="data row4 col2" >120.01%</td>
#     </tr>
#     <tr>
#       <th id="T_aee36_level0_row5" class="row_heading level0 row5" >cv_high</th>
#       <td id="T_aee36_row5_col0" class="data row5 col0" >2.86%</td>
#       <td id="T_aee36_row5_col1" class="data row5 col1" >2.14%</td>
#       <td id="T_aee36_row5_col2" class="data row5 col2" >163.97%</td>
#     </tr>
#     <tr>
#       <th id="T_aee36_level0_row6" class="row_heading level0 row6" >cv_std</th>
#       <td id="T_aee36_row6_col0" class="data row6 col0" >0.14%</td>
#       <td id="T_aee36_row6_col1" class="data row6 col1" >0.19%</td>
#       <td id="T_aee36_row6_col2" class="data row6 col2" >19.42%</td>
#     </tr>
#   </tbody>
# </table>

# %%
len([c for c in cv_valpreds["cv_to_val_test_map"][0]["test"].columns if c.startswith("pred_target_")])
# Out:
# 36

# %% [markdown]
# ### 3.2 Average top 8 target models

# %%
bl_top8pred_mean_metrics = score_baselines(
    cv_valpreds=cv_valpreds,
    predcols_subset=[
    "pred_target_cyrus_v4_20",
    "pred_target_ralph_v4_20",
    "pred_target_sam_v4_20",
    "pred_target_xerxes_v4_20",
    "pred_target_caroline_v4_20",
    "pred_target_waldo_v4_20",
    "pred_target_nomi_v4_20",
    "pred_target_tyler_v4_20",
    ],
    agg_fn=np.mean,
    baseline_name="top8preds_mean",
)
# Out:
# CV split:   0%|          | 0/3 [00:00<?, ?it/s]
# [2023-04-28 21:58:16]  split=0, train_df[predcols].shape=(587086, 36), train_df.era.min()=820, train_df.era.max()=935, train_df.era.nunique()=116
# [2023-04-28 21:58:16]  split=0, test_df[predcols].shape=(590333, 36), test_df.era.min()=948, test_df.era.max()=1059, test_df.era.nunique()=112
# [2023-04-28 21:58:16]  Chosen 8 features:
# ['pred_target_cyrus_v4_20_cv0', 'pred_target_caroline_v4_20_cv0', 'pred_target_sam_v4_20_cv0', 'pred_target_xerxes_v4_20_cv0', 'pred_target_nomi_v4_20_cv0', 'pred_target_tyler_v4_20_cv0', 'pred_target_ralph_v4_20_cv0', 'pred_target_waldo_v4_20_cv0']
# [2023-04-28 21:58:17]  split=1, train_df[predcols].shape=(571392, 36), train_df.era.min()=556, train_df.era.max()=671, train_df.era.nunique()=116
# [2023-04-28 21:58:18]  split=1, test_df[predcols].shape=(571414, 36), test_df.era.min()=684, test_df.era.max()=795, test_df.era.nunique()=112
# [2023-04-28 21:58:18]  Chosen 8 features:
# ['pred_target_cyrus_v4_20_cv1', 'pred_target_caroline_v4_20_cv1', 'pred_target_sam_v4_20_cv1', 'pred_target_xerxes_v4_20_cv1', 'pred_target_nomi_v4_20_cv1', 'pred_target_tyler_v4_20_cv1', 'pred_target_ralph_v4_20_cv1', 'pred_target_waldo_v4_20_cv1']
# [2023-04-28 21:58:19]  split=2, train_df[predcols].shape=(500976, 36), train_df.era.min()=292, train_df.era.max()=408, train_df.era.nunique()=117
# [2023-04-28 21:58:19]  split=2, test_df[predcols].shape=(507469, 36), test_df.era.min()=421, test_df.era.max()=531, test_df.era.nunique()=111
# [2023-04-28 21:58:19]  Chosen 8 features:
# ['pred_target_cyrus_v4_20_cv2', 'pred_target_caroline_v4_20_cv2', 'pred_target_sam_v4_20_cv2', 'pred_target_xerxes_v4_20_cv2', 'pred_target_nomi_v4_20_cv2', 'pred_target_tyler_v4_20_cv2', 'pred_target_ralph_v4_20_cv2', 'pred_target_waldo_v4_20_cv2']
# [2023-04-28 21:58:20]  Prediction distribution
#        ensemble_top8preds_mean_cv0  ensemble_top8preds_mean_cv1  \
# count                590333.000000                571414.000000
# mean                      0.499296                     0.500676
# std                       0.015129                     0.017853
# min                       0.410754                     0.413525
# 25%                       0.489624                     0.488847
# 50%                       0.499210                     0.500145
# 75%                       0.509048                     0.511997
# max                       0.574484                     0.608171
#
#        ensemble_top8preds_mean_cv2
# count                507469.000000
# mean                      0.500170
# std                       0.024679
# min                       0.355457
# 25%                       0.484232
# 50%                       0.499550
# 75%                       0.515318
# max                       0.668130
# <style type="text/css">
# #T_07366   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_07366 thead {
#   background-color: lightblue;
# }
# #T_07366 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_07366 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_07366 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_07366 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_07366_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 91.3%, transparent 91.3%);
# }
# #T_07366_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.5%, transparent 99.5%);
# }
# #T_07366_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 82.0%, transparent 82.0%);
# }
# #T_07366_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.3%, transparent 97.3%);
# }
# #T_07366_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.3%, transparent 93.3%);
# }
# #T_07366_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 91.8%, transparent 91.8%);
# }
# #T_07366_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.4%, transparent 98.4%);
# }
# #T_07366_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.4%, transparent 88.4%);
# }
# #T_07366_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.3%, transparent 98.3%);
# }
# #T_07366_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 95.7%, transparent 95.7%);
# }
# #T_07366_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.7%, transparent 93.7%);
# }
# #T_07366_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.7%, transparent 90.7%);
# }
# #T_07366_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 91.4%, transparent 91.4%);
# }
# #T_07366_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.4%, transparent 87.4%);
# }
# #T_07366_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 81.4%, transparent 81.4%);
# }
# #T_07366_row5_col0, #T_07366_row5_col1, #T_07366_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_07366_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 53.8%, transparent 53.8%);
# }
# #T_07366_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 55.6%, transparent 55.6%);
# }
# #T_07366_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 58.2%, transparent 58.2%);
# }
# </style>
# <table id="T_07366">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07366_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_07366_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_07366_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07366_level0_row0" class="row_heading level0 row0" >ensemble_top8preds_mean_cv0</th>
#       <td id="T_07366_row0_col0" class="data row0 col0" >2.60%</td>
#       <td id="T_07366_row0_col1" class="data row0 col1" >2.13%</td>
#       <td id="T_07366_row0_col2" class="data row0 col2" >122.04%</td>
#     </tr>
#     <tr>
#       <th id="T_07366_level0_row1" class="row_heading level0 row1" >ensemble_top8preds_mean_cv1</th>
#       <td id="T_07366_row1_col0" class="data row1 col0" >2.97%</td>
#       <td id="T_07366_row1_col1" class="data row1 col1" >1.87%</td>
#       <td id="T_07366_row1_col2" class="data row1 col2" >159.35%</td>
#     </tr>
#     <tr>
#       <th id="T_07366_level0_row2" class="row_heading level0 row2" >ensemble_top8preds_mean_cv2</th>
#       <td id="T_07366_row2_col0" class="data row2 col0" >3.05%</td>
#       <td id="T_07366_row2_col1" class="data row2 col1" >1.65%</td>
#       <td id="T_07366_row2_col2" class="data row2 col2" >184.33%</td>
#     </tr>
#     <tr>
#       <th id="T_07366_level0_row3" class="row_heading level0 row3" >cv_mean</th>
#       <td id="T_07366_row3_col0" class="data row3 col0" >2.87%</td>
#       <td id="T_07366_row3_col1" class="data row3 col1" >1.88%</td>
#       <td id="T_07366_row3_col2" class="data row3 col2" >155.24%</td>
#     </tr>
#     <tr>
#       <th id="T_07366_level0_row4" class="row_heading level0 row4" >cv_low</th>
#       <td id="T_07366_row4_col0" class="data row4 col0" >2.60%</td>
#       <td id="T_07366_row4_col1" class="data row4 col1" >1.61%</td>
#       <td id="T_07366_row4_col2" class="data row4 col2" >119.76%</td>
#     </tr>
#     <tr>
#       <th id="T_07366_level0_row5" class="row_heading level0 row5" >cv_high</th>
#       <td id="T_07366_row5_col0" class="data row5 col0" >3.15%</td>
#       <td id="T_07366_row5_col1" class="data row5 col1" >2.15%</td>
#       <td id="T_07366_row5_col2" class="data row5 col2" >190.71%</td>
#     </tr>
#     <tr>
#       <th id="T_07366_level0_row6" class="row_heading level0 row6" >cv_std</th>
#       <td id="T_07366_row6_col0" class="data row6 col0" >0.24%</td>
#       <td id="T_07366_row6_col1" class="data row6 col1" >0.24%</td>
#       <td id="T_07366_row6_col2" class="data row6 col2" >31.35%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.3 Only cyrus

# %%
bl_cyrus_metrics = score_baselines(
    cv_valpreds=cv_valpreds,
    predcols_subset=[
    "pred_target_cyrus_v4_20",
    ],
    agg_fn=np.mean,
    baseline_name="top8preds_mean",
)
# Out:
# CV split:   0%|          | 0/3 [00:00<?, ?it/s]
# [2023-04-28 21:58:06]  split=0, train_df[predcols].shape=(587086, 36), train_df.era.min()=820, train_df.era.max()=935, train_df.era.nunique()=116
# [2023-04-28 21:58:06]  split=0, test_df[predcols].shape=(590333, 36), test_df.era.min()=948, test_df.era.max()=1059, test_df.era.nunique()=112
# [2023-04-28 21:58:06]  Chosen 1 features:
# ['pred_target_cyrus_v4_20_cv0']
# [2023-04-28 21:58:08]  split=1, train_df[predcols].shape=(571392, 36), train_df.era.min()=556, train_df.era.max()=671, train_df.era.nunique()=116
# [2023-04-28 21:58:08]  split=1, test_df[predcols].shape=(571414, 36), test_df.era.min()=684, test_df.era.max()=795, test_df.era.nunique()=112
# [2023-04-28 21:58:08]  Chosen 1 features:
# ['pred_target_cyrus_v4_20_cv1']
# [2023-04-28 21:58:09]  split=2, train_df[predcols].shape=(500976, 36), train_df.era.min()=292, train_df.era.max()=408, train_df.era.nunique()=117
# [2023-04-28 21:58:09]  split=2, test_df[predcols].shape=(507469, 36), test_df.era.min()=421, test_df.era.max()=531, test_df.era.nunique()=111
# [2023-04-28 21:58:09]  Chosen 1 features:
# ['pred_target_cyrus_v4_20_cv2']
# [2023-04-28 21:58:11]  Prediction distribution
#        ensemble_top8preds_mean_cv0  ensemble_top8preds_mean_cv1  \
# count                590333.000000                571414.000000
# mean                      0.499325                     0.500647
# std                       0.015416                     0.018196
# min                       0.399952                     0.391883
# 25%                       0.489571                     0.488724
# 50%                       0.499304                     0.500166
# 75%                       0.509175                     0.512116
# max                       0.583978                     0.622373
#
#        ensemble_top8preds_mean_cv2
# count                507469.000000
# mean                      0.499923
# std                       0.026042
# min                       0.340739
# 25%                       0.483367
# 50%                       0.499483
# 75%                       0.515794
# max                       0.680007
# <style type="text/css">
# #T_1e9a1   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_1e9a1 thead {
#   background-color: lightblue;
# }
# #T_1e9a1 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_1e9a1 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_1e9a1 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_1e9a1 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_1e9a1_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.3%, transparent 88.3%);
# }
# #T_1e9a1_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.4%, transparent 98.4%);
# }
# #T_1e9a1_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 81.3%, transparent 81.3%);
# }
# #T_1e9a1_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 96.6%, transparent 96.6%);
# }
# #T_1e9a1_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 95.8%, transparent 95.8%);
# }
# #T_1e9a1_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.2%, transparent 90.2%);
# }
# #T_1e9a1_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.7%, transparent 97.7%);
# }
# #T_1e9a1_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.6%, transparent 88.6%);
# }
# #T_1e9a1_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.8%, transparent 98.8%);
# }
# #T_1e9a1_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.2%, transparent 94.2%);
# }
# #T_1e9a1_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.3%, transparent 94.3%);
# }
# #T_1e9a1_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.1%, transparent 90.1%);
# }
# #T_1e9a1_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.4%, transparent 88.4%);
# }
# #T_1e9a1_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.5%, transparent 88.5%);
# }
# #T_1e9a1_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 80.2%, transparent 80.2%);
# }
# #T_1e9a1_row5_col0, #T_1e9a1_row5_col1, #T_1e9a1_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_1e9a1_row6_col0, #T_1e9a1_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 55.1%, transparent 55.1%);
# }
# #T_1e9a1_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 58.8%, transparent 58.8%);
# }
# </style>
# <table id="T_1e9a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e9a1_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_1e9a1_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_1e9a1_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e9a1_level0_row0" class="row_heading level0 row0" >ensemble_top8preds_mean_cv0</th>
#       <td id="T_1e9a1_row0_col0" class="data row0 col0" >2.40%</td>
#       <td id="T_1e9a1_row0_col1" class="data row0 col1" >2.07%</td>
#       <td id="T_1e9a1_row0_col2" class="data row0 col2" >115.92%</td>
#     </tr>
#     <tr>
#       <th id="T_1e9a1_level0_row1" class="row_heading level0 row1" >ensemble_top8preds_mean_cv1</th>
#       <td id="T_1e9a1_row1_col0" class="data row1 col0" >2.92%</td>
#       <td id="T_1e9a1_row1_col1" class="data row1 col1" >1.95%</td>
#       <td id="T_1e9a1_row1_col2" class="data row1 col2" >149.20%</td>
#     </tr>
#     <tr>
#       <th id="T_1e9a1_level0_row2" class="row_heading level0 row2" >ensemble_top8preds_mean_cv2</th>
#       <td id="T_1e9a1_row2_col0" class="data row2 col0" >2.98%</td>
#       <td id="T_1e9a1_row2_col1" class="data row2 col1" >1.65%</td>
#       <td id="T_1e9a1_row2_col2" class="data row2 col2" >180.92%</td>
#     </tr>
#     <tr>
#       <th id="T_1e9a1_level0_row3" class="row_heading level0 row3" >cv_mean</th>
#       <td id="T_1e9a1_row3_col0" class="data row3 col0" >2.77%</td>
#       <td id="T_1e9a1_row3_col1" class="data row3 col1" >1.89%</td>
#       <td id="T_1e9a1_row3_col2" class="data row3 col2" >148.68%</td>
#     </tr>
#     <tr>
#       <th id="T_1e9a1_level0_row4" class="row_heading level0 row4" >cv_low</th>
#       <td id="T_1e9a1_row4_col0" class="data row4 col0" >2.40%</td>
#       <td id="T_1e9a1_row4_col1" class="data row4 col1" >1.65%</td>
#       <td id="T_1e9a1_row4_col2" class="data row4 col2" >111.90%</td>
#     </tr>
#     <tr>
#       <th id="T_1e9a1_level0_row5" class="row_heading level0 row5" >cv_high</th>
#       <td id="T_1e9a1_row5_col0" class="data row5 col0" >3.13%</td>
#       <td id="T_1e9a1_row5_col1" class="data row5 col1" >2.14%</td>
#       <td id="T_1e9a1_row5_col2" class="data row5 col2" >185.46%</td>
#     </tr>
#     <tr>
#       <th id="T_1e9a1_level0_row6" class="row_heading level0 row6" >cv_std</th>
#       <td id="T_1e9a1_row6_col0" class="data row6 col0" >0.32%</td>
#       <td id="T_1e9a1_row6_col1" class="data row6 col1" >0.22%</td>
#       <td id="T_1e9a1_row6_col2" class="data row6 col2" >32.50%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ut.fmt_metrics_df(bl_cyrus_metrics.loc[["cv_mean"]], add_bar=False)
# Out:
# <style type="text/css">
# #T_fc98a   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_fc98a thead {
#   background-color: lightblue;
# }
# #T_fc98a tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_fc98a tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_fc98a td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_fc98a th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_fc98a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc98a_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_fc98a_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_fc98a_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc98a_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_fc98a_row0_col0" class="data row0 col0" >2.77%</td>
#       <td id="T_fc98a_row0_col1" class="data row0 col1" >1.89%</td>
#       <td id="T_fc98a_row0_col2" class="data row0 col2" >148.68%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4.1 Sequential feature selection with RidgeRegression

# %%
import sklearn.linear_model as sklin
import sklearn.base

# %%
PREDCOL_PREFIXES = [c[:-4] for c in cv_valpreds["cv_predcols_map"][0]]
log.info(PREDCOL_PREFIXES)
# Out:
# [2023-04-28 21:45:16]  ['pred_target_arthur_v4_20', 'pred_target_arthur_v4_60', 'pred_target_thomas_v4_20', 'pred_target_thomas_v4_60', 'pred_target_cyrus_v4_20', 'pred_target_cyrus_v4_60', 'pred_target_caroline_v4_20', 'pred_target_caroline_v4_60', 'pred_target_sam_v4_20', 'pred_target_sam_v4_60', 'pred_target_xerxes_v4_20', 'pred_target_xerxes_v4_60', 'pred_target_nomi_v4_20', 'pred_target_nomi_v4_60', 'pred_target_tyler_v4_20', 'pred_target_tyler_v4_60', 'pred_target_victor_v4_20', 'pred_target_victor_v4_60', 'pred_target_ralph_v4_20', 'pred_target_ralph_v4_60', 'pred_target_waldo_v4_20', 'pred_target_waldo_v4_60', 'pred_target_jerome_v4_20', 'pred_target_jerome_v4_60', 'pred_target_janet_v4_20', 'pred_target_janet_v4_60', 'pred_target_ben_v4_20', 'pred_target_ben_v4_60', 'pred_target_alan_v4_20', 'pred_target_alan_v4_60', 'pred_target_paul_v4_20', 'pred_target_paul_v4_60', 'pred_target_george_v4_20', 'pred_target_george_v4_60', 'pred_target_william_v4_20', 'pred_target_william_v4_60']

# %%
def xval(
    cv_valpreds,
    untrained_mdl,
    model_nm_prefix="",
    pcols_like_list=None,
    overwrite_models=False,
    verbose=1,
    to_split_train=False,
):
    """Cross validates the ensemble model.
    
    :param verbose: > 0 prints everything, -1 just coefficients and average cv perf
        and < -1, nothing.
    :param pcols_like_list: A list of partial predcol names to select
        a subset of predcols. Example: `['pred_target_sam_v4_20']` will
        select `pred_target_sam_v4_20_cv0`, `pred_target_sam_v4_20_cv1`
        and `pred_target_sam_v4_20_cv2`.
    :param to_split_train: split train into half for training and testing. Don't use
        the test set at all.
    """
    cv = len(cv_valpreds["cv_predcols_map"])
    ensmbl_cv_models, ensmbl_cv_predcols, ensmbl_cv_metrics = [], [], []
    cv_pred_descs, cv_num_feats, cv_coef_dfs = [], [], []
    verbose_pos = verbose > 0

    raw_iterand = zip(
        range(cv),
        cv_valpreds["cv_predcols_map"],
        cv_valpreds["cv_to_val_test_map"],
    )
    if verbose_pos:
        iterand = tqdm(raw_iterand, desc="CV split", total=cv)
    else:
        iterand = raw_iterand
    for split, predcols, val_test_map in iterand:
        model_nm = f"{model_nm_prefix}_cv{split}.pkl"
        if to_split_train:
            val_df = val_test_map["val"]
            median = np.median(val_df[ERA_COL].unique())
            train_df = val_df[val_df[ERA_COL] < median]
            test_df = val_df[val_df[ERA_COL] > median + 12]
        else:
            train_df, test_df = val_test_map["val"], val_test_map["test"]
        if pcols_like_list is None:
            chosen_cols = predcols
        else:
            chosen_cols = extract_cols_like(all_cols=predcols, match_cols=pcols_like_list)
        # Try to load the trained model
        loaded_mdl = ut.load_model(model_nm, model_folder=MODEL_DIR)
        train_st_tm = time.time()
        if loaded_mdl and not overwrite_models:
            if verbose_pos:
                log.info(f"Loaded saved model: `{model_nm}`")
            split_mdl = loaded_mdl
        else:
            if verbose_pos:
                log.info(f"Training new model. No model named `{model_nm}` saved...")
            split_mdl = sklearn.base.clone(untrained_mdl)
            # Use train and test df which have prediction columns from models trained on
            # each target, cval split
            if verbose_pos:
                log.info(
                    f"{split=}, {train_df[chosen_cols].shape=}, {train_df.era.min()=}, "
                    f"{train_df.era.max()=}, {train_df.era.nunique()=}",
                )
            # We don't have to filter out NAs as cyrus doesn't have NA values.
            if verbose_pos:
                log.info(f"Training model on {len(chosen_cols)} columns: {chosen_cols}")
            split_mdl.fit(X=train_df[chosen_cols], y=train_df[TARGET_COL])
            if verbose_pos:
                log.info(f"Saving the trained model `{model_nm}`...")
            ut.save_model(model=split_mdl, name=model_nm, model_folder=MODEL_DIR)
        # Model coefficients
        cv_coef_dfs.append(
            pd.DataFrame(
                {f"coef_cv{split}": np.concatenate(([split_mdl.intercept_], split_mdl.coef_))},
                index=["intercept"] + [refmt_predcols(c) for c in chosen_cols],
            )
        )
        ensmbl_predcol = f"ensemble_{model_nm_prefix}__cv{split}"
        if verbose_pos:
            log.info(f"Predicting column: {ensmbl_predcol}")
        test_df[ensmbl_predcol] = split_mdl.predict(X=test_df[chosen_cols])
        metrics_df = ut.validation_metrics(
            validation_data=test_df, pred_cols=[ensmbl_predcol], target_col=TARGET_COL
        )
        # Get stats on number of zeroed out features
        z_coef = split_mdl.coef_==0
        cv_num_feats.append((~z_coef).sum())
        if verbose_pos:
            log.info(f"Percent of zero columns: {z_coef.mean():.0%} ({z_coef.sum()}/{len(z_coef)})")
            log.info(f"Training time: {(time.time() - train_st_tm):.0f} seconds\n")
        # collect data for saving
        ensmbl_cv_models.append(split_mdl)
        ensmbl_cv_predcols.append(ensmbl_predcol)
        ensmbl_cv_metrics.append(metrics_df)
        cv_pred_descs.append(test_df[ensmbl_predcol].describe())
    if verbose_pos:
        log.info("Prediction distribution")
        display(pd.concat(cv_pred_descs, axis=1))
    cv_metrics = ut.to_cv_agg_df(ensmbl_cv_metrics)
    coefs_df = pd.concat(cv_coef_dfs, axis=1).transpose()
    coefs_df.loc['avg'] = coefs_df.mean(axis=0)
    if verbose == -1:
        display(coefs_df.style.bar(align="zero", color=["#d65f5f", "#74A662"]))
        display(cv_metrics.loc[["cv_mean"]])
    return {
        "cv_models": ensmbl_cv_models,
        "cv_pred_cols": ensmbl_cv_predcols,
        "cv_metrics": cv_metrics,
        "num_feats": int(np.mean(cv_num_feats)),
        "coefs": coefs_df,
    }

# %%
SFS_MAXCOLS = 8
SFS_RIDGE_PARAMS = dict(alpha=100., fit_intercept=False, random_state=42)
SFS_ESTIMATOR = sklin.Ridge(**SFS_RIDGE_PARAMS)
CHOSEN_METRIC = "sharpe"

# %%
def get_best_ft(ft_metric_map, metric):
    """Given a dict mapping key to scores, returns key with max score"""
    return sorted(ft_metric_map.items(), key=lambda kv: -kv[1].loc["cv_mean", metric])[0][0]

# %%
chosen_features = ["pred_target_cyrus_v4_20"]

num_feats_to_add = SFS_MAXCOLS-len(chosen_features)
for i in tqdm(range(num_feats_to_add), total=num_feats_to_add, desc="Rounds"):
    ft_opts = sorted(c for c in PREDCOL_PREFIXES if c not in chosen_features)
    ft_metric_map = {}
    ft_coef_map = {}
    for ft_to_try in tqdm(ft_opts, desc="Trying feature"):
        xval_res = xval(
            cv_valpreds=cv_valpreds,
            untrained_mdl=sklearn.base.clone(SFS_ESTIMATOR),
            model_nm_prefix=f"sfs_{hash(tuple(chosen_features + [ft_to_try]))}",
            pcols_like_list=chosen_features + [ft_to_try],
            overwrite_models=True,
            verbose=-2,
            to_split_train=True,
        )
        ft_metric_map[ft_to_try] = xval_res["cv_metrics"].loc[["cv_mean"]]
        ft_coef_map[ft_to_try] = xval_res['coefs']
        #display(ft_metric_map[ft_to_try])
    best_ft = get_best_ft(ft_metric_map, metric="mean")   # metric to choose feature
    best_metrics = ft_metric_map[best_ft]
    
    log.info(f"Best ft in round {i} is {best_ft} with validation metrics:")
    display(ut.fmt_metrics_df(best_metrics, add_bar=False))
    # With the new feature added, cross validate on out of sample test set
    chosen_features.append(best_ft)
    oos_metrics = xval(
        cv_valpreds=cv_valpreds,
        untrained_mdl=sklearn.base.clone(SFS_ESTIMATOR),
        model_nm_prefix=f"sfs_full_{hash(tuple(chosen_features))}",
        pcols_like_list=chosen_features,
        overwrite_models=True,
        verbose=-2,
        to_split_train=False,
    )["cv_metrics"].loc[["cv_mean"]]
    log.info(f"Best ft in round {i} is {best_ft} with test metrics:")
    display(ut.fmt_metrics_df(oos_metrics, add_bar=False))
    
    log.info(f"Adding {best_ft}...")
    display(ut.fmt_metrics_df(ft_coef_map[best_ft]))
# Out:
# Rounds:   0%|          | 0/7 [00:00<?, ?it/s]
# Trying feature:   0%|          | 0/35 [00:00<?, ?it/s]
# [2023-04-28 21:52:32]  Best ft in round 0 is pred_target_waldo_v4_20 with validation metrics:
# <style type="text/css">
# #T_4e3e1   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_4e3e1 thead {
#   background-color: lightblue;
# }
# #T_4e3e1 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_4e3e1 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_4e3e1 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_4e3e1 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_4e3e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e3e1_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_4e3e1_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_4e3e1_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e3e1_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_4e3e1_row0_col0" class="data row0 col0" >3.09%</td>
#       <td id="T_4e3e1_row0_col1" class="data row0 col1" >1.66%</td>
#       <td id="T_4e3e1_row0_col2" class="data row0 col2" >197.32%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:52:36]  Best ft in round 0 is pred_target_waldo_v4_20 with test metrics:
# <style type="text/css">
# #T_31d0d   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_31d0d thead {
#   background-color: lightblue;
# }
# #T_31d0d tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_31d0d tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_31d0d td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_31d0d th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_31d0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31d0d_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_31d0d_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_31d0d_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31d0d_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_31d0d_row0_col0" class="data row0 col0" >2.86%</td>
#       <td id="T_31d0d_row0_col1" class="data row0 col1" >1.89%</td>
#       <td id="T_31d0d_row0_col2" class="data row0 col2" >154.02%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:52:36]  Adding pred_target_waldo_v4_20...
# <style type="text/css">
# #T_ce315   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_ce315 thead {
#   background-color: lightblue;
# }
# #T_ce315 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_ce315 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_ce315 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_ce315 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_ce315_row0_col0, #T_ce315_row1_col0, #T_ce315_row2_col0, #T_ce315_row3_col0 {
#   width: 10em;
# }
# #T_ce315_row0_col1, #T_ce315_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_ce315_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.2%, transparent 99.2%);
# }
# #T_ce315_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.4%, transparent 99.4%);
# }
# #T_ce315_row1_col2, #T_ce315_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.6%, transparent 99.6%);
# }
# #T_ce315_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.1%, transparent 99.1%);
# }
# #T_ce315_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.5%, transparent 99.5%);
# }
# </style>
# <table id="T_ce315">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce315_level0_col0" class="col_heading level0 col0" >intercept</th>
#       <th id="T_ce315_level0_col1" class="col_heading level0 col1" >cyrus_v4_20</th>
#       <th id="T_ce315_level0_col2" class="col_heading level0 col2" >waldo_v4_20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce315_level0_row0" class="row_heading level0 row0" >coef_cv0</th>
#       <td id="T_ce315_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_ce315_row0_col1" class="data row0 col1" >53.39%</td>
#       <td id="T_ce315_row0_col2" class="data row0 col2" >46.59%</td>
#     </tr>
#     <tr>
#       <th id="T_ce315_level0_row1" class="row_heading level0 row1" >coef_cv1</th>
#       <td id="T_ce315_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_ce315_row1_col1" class="data row1 col1" >52.75%</td>
#       <td id="T_ce315_row1_col2" class="data row1 col2" >47.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ce315_level0_row2" class="row_heading level0 row2" >coef_cv2</th>
#       <td id="T_ce315_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_ce315_row2_col1" class="data row2 col1" >52.46%</td>
#       <td id="T_ce315_row2_col2" class="data row2 col2" >47.37%</td>
#     </tr>
#     <tr>
#       <th id="T_ce315_level0_row3" class="row_heading level0 row3" >avg</th>
#       <td id="T_ce315_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_ce315_row3_col1" class="data row3 col1" >52.87%</td>
#       <td id="T_ce315_row3_col2" class="data row3 col2" >46.99%</td>
#     </tr>
#   </tbody>
# </table>
# Trying feature:   0%|          | 0/34 [00:00<?, ?it/s]
# [2023-04-28 21:53:02]  Best ft in round 1 is pred_target_victor_v4_20 with validation metrics:
# <style type="text/css">
# #T_9d0db   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_9d0db thead {
#   background-color: lightblue;
# }
# #T_9d0db tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_9d0db tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_9d0db td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_9d0db th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_9d0db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d0db_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_9d0db_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_9d0db_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d0db_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_9d0db_row0_col0" class="data row0 col0" >3.14%</td>
#       <td id="T_9d0db_row0_col1" class="data row0 col1" >1.61%</td>
#       <td id="T_9d0db_row0_col2" class="data row0 col2" >202.71%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:53:05]  Best ft in round 1 is pred_target_victor_v4_20 with test metrics:
# <style type="text/css">
# #T_f856c   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_f856c thead {
#   background-color: lightblue;
# }
# #T_f856c tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_f856c tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_f856c td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_f856c th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_f856c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f856c_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_f856c_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_f856c_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f856c_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_f856c_row0_col0" class="data row0 col0" >2.83%</td>
#       <td id="T_f856c_row0_col1" class="data row0 col1" >1.88%</td>
#       <td id="T_f856c_row0_col2" class="data row0 col2" >152.76%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:53:05]  Adding pred_target_victor_v4_20...
# <style type="text/css">
# #T_38004   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_38004 thead {
#   background-color: lightblue;
# }
# #T_38004 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_38004 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_38004 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_38004 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_38004_row0_col0, #T_38004_row1_col0, #T_38004_row2_col0, #T_38004_row3_col0 {
#   width: 10em;
# }
# #T_38004_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.2%, transparent 97.2%);
# }
# #T_38004_row0_col2, #T_38004_row1_col1, #T_38004_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_38004_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.6%, transparent 94.6%);
# }
# #T_38004_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.3%, transparent 92.3%);
# }
# #T_38004_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.4%, transparent 99.4%);
# }
# #T_38004_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.0%, transparent 99.0%);
# }
# #T_38004_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.0%, transparent 93.0%);
# }
# #T_38004_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.7%, transparent 98.7%);
# }
# #T_38004_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 95.1%, transparent 95.1%);
# }
# #T_38004_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.0%, transparent 98.0%);
# }
# </style>
# <table id="T_38004">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38004_level0_col0" class="col_heading level0 col0" >intercept</th>
#       <th id="T_38004_level0_col1" class="col_heading level0 col1" >cyrus_v4_20</th>
#       <th id="T_38004_level0_col2" class="col_heading level0 col2" >victor_v4_20</th>
#       <th id="T_38004_level0_col3" class="col_heading level0 col3" >waldo_v4_20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38004_level0_row0" class="row_heading level0 row0" >coef_cv0</th>
#       <td id="T_38004_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_38004_row0_col1" class="data row0 col1" >35.07%</td>
#       <td id="T_38004_row0_col2" class="data row0 col2" >35.78%</td>
#       <td id="T_38004_row0_col3" class="data row0 col3" >29.14%</td>
#     </tr>
#     <tr>
#       <th id="T_38004_level0_row1" class="row_heading level0 row1" >coef_cv1</th>
#       <td id="T_38004_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_38004_row1_col1" class="data row1 col1" >37.15%</td>
#       <td id="T_38004_row1_col2" class="data row1 col2" >30.30%</td>
#       <td id="T_38004_row1_col3" class="data row1 col3" >32.33%</td>
#     </tr>
#     <tr>
#       <th id="T_38004_level0_row2" class="row_heading level0 row2" >coef_cv2</th>
#       <td id="T_38004_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_38004_row2_col1" class="data row2 col1" >36.40%</td>
#       <td id="T_38004_row2_col2" class="data row2 col2" >30.75%</td>
#       <td id="T_38004_row2_col3" class="data row2 col3" >32.70%</td>
#     </tr>
#     <tr>
#       <th id="T_38004_level0_row3" class="row_heading level0 row3" >avg</th>
#       <td id="T_38004_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_38004_row3_col1" class="data row3 col1" >36.21%</td>
#       <td id="T_38004_row3_col2" class="data row3 col2" >32.28%</td>
#       <td id="T_38004_row3_col3" class="data row3 col3" >31.39%</td>
#     </tr>
#   </tbody>
# </table>
# Trying feature:   0%|          | 0/33 [00:00<?, ?it/s]
# [2023-04-28 21:53:30]  Best ft in round 2 is pred_target_tyler_v4_20 with validation metrics:
# <style type="text/css">
# #T_50cb8   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_50cb8 thead {
#   background-color: lightblue;
# }
# #T_50cb8 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_50cb8 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_50cb8 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_50cb8 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_50cb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50cb8_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_50cb8_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_50cb8_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50cb8_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_50cb8_row0_col0" class="data row0 col0" >3.15%</td>
#       <td id="T_50cb8_row0_col1" class="data row0 col1" >1.64%</td>
#       <td id="T_50cb8_row0_col2" class="data row0 col2" >200.17%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:53:33]  Best ft in round 2 is pred_target_tyler_v4_20 with test metrics:
# <style type="text/css">
# #T_dc6a1   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_dc6a1 thead {
#   background-color: lightblue;
# }
# #T_dc6a1 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_dc6a1 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_dc6a1 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_dc6a1 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_dc6a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc6a1_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_dc6a1_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_dc6a1_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc6a1_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_dc6a1_row0_col0" class="data row0 col0" >2.83%</td>
#       <td id="T_dc6a1_row0_col1" class="data row0 col1" >1.87%</td>
#       <td id="T_dc6a1_row0_col2" class="data row0 col2" >154.50%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:53:33]  Adding pred_target_tyler_v4_20...
# <style type="text/css">
# #T_d0c05   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_d0c05 thead {
#   background-color: lightblue;
# }
# #T_d0c05 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_d0c05 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_d0c05 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_d0c05 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_d0c05_row0_col0, #T_d0c05_row1_col0, #T_d0c05_row2_col0, #T_d0c05_row3_col0 {
#   width: 10em;
# }
# #T_d0c05_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.3%, transparent 97.3%);
# }
# #T_d0c05_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.4%, transparent 93.4%);
# }
# #T_d0c05_row0_col3, #T_d0c05_row1_col1, #T_d0c05_row1_col4, #T_d0c05_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_d0c05_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.8%, transparent 94.8%);
# }
# #T_d0c05_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.7%, transparent 97.7%);
# }
# #T_d0c05_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.6%, transparent 88.6%);
# }
# #T_d0c05_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.4%, transparent 98.4%);
# }
# #T_d0c05_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.4%, transparent 88.4%);
# }
# #T_d0c05_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 99.7%, transparent 99.7%);
# }
# #T_d0c05_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.6%, transparent 98.6%);
# }
# #T_d0c05_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.0%, transparent 97.0%);
# }
# #T_d0c05_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.3%, transparent 92.3%);
# }
# #T_d0c05_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.2%, transparent 98.2%);
# }
# </style>
# <table id="T_d0c05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0c05_level0_col0" class="col_heading level0 col0" >intercept</th>
#       <th id="T_d0c05_level0_col1" class="col_heading level0 col1" >cyrus_v4_20</th>
#       <th id="T_d0c05_level0_col2" class="col_heading level0 col2" >tyler_v4_20</th>
#       <th id="T_d0c05_level0_col3" class="col_heading level0 col3" >victor_v4_20</th>
#       <th id="T_d0c05_level0_col4" class="col_heading level0 col4" >waldo_v4_20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0c05_level0_row0" class="row_heading level0 row0" >coef_cv0</th>
#       <td id="T_d0c05_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_d0c05_row0_col1" class="data row0 col1" >27.73%</td>
#       <td id="T_d0c05_row0_col2" class="data row0 col2" >22.99%</td>
#       <td id="T_d0c05_row0_col3" class="data row0 col3" >28.31%</td>
#       <td id="T_d0c05_row0_col4" class="data row0 col4" >20.98%</td>
#     </tr>
#     <tr>
#       <th id="T_d0c05_level0_row1" class="row_heading level0 row1" >coef_cv1</th>
#       <td id="T_d0c05_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_d0c05_row1_col1" class="data row1 col1" >29.29%</td>
#       <td id="T_d0c05_row1_col2" class="data row1 col2" >25.30%</td>
#       <td id="T_d0c05_row1_col3" class="data row1 col3" >21.84%</td>
#       <td id="T_d0c05_row1_col4" class="data row1 col4" >23.39%</td>
#     </tr>
#     <tr>
#       <th id="T_d0c05_level0_row2" class="row_heading level0 row2" >coef_cv2</th>
#       <td id="T_d0c05_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_d0c05_row2_col1" class="data row2 col1" >28.35%</td>
#       <td id="T_d0c05_row2_col2" class="data row2 col2" >26.50%</td>
#       <td id="T_d0c05_row2_col3" class="data row2 col3" >21.76%</td>
#       <td id="T_d0c05_row2_col4" class="data row2 col4" >23.23%</td>
#     </tr>
#     <tr>
#       <th id="T_d0c05_level0_row3" class="row_heading level0 row3" >avg</th>
#       <td id="T_d0c05_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_d0c05_row3_col1" class="data row3 col1" >28.46%</td>
#       <td id="T_d0c05_row3_col2" class="data row3 col2" >24.93%</td>
#       <td id="T_d0c05_row3_col3" class="data row3 col3" >23.97%</td>
#       <td id="T_d0c05_row3_col4" class="data row3 col4" >22.53%</td>
#     </tr>
#   </tbody>
# </table>
# Trying feature:   0%|          | 0/32 [00:00<?, ?it/s]
# [2023-04-28 21:53:57]  Best ft in round 3 is pred_target_alan_v4_60 with validation metrics:
# <style type="text/css">
# #T_63ba3   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_63ba3 thead {
#   background-color: lightblue;
# }
# #T_63ba3 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_63ba3 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_63ba3 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_63ba3 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_63ba3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63ba3_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_63ba3_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_63ba3_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63ba3_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_63ba3_row0_col0" class="data row0 col0" >3.17%</td>
#       <td id="T_63ba3_row0_col1" class="data row0 col1" >1.68%</td>
#       <td id="T_63ba3_row0_col2" class="data row0 col2" >196.46%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:54:00]  Best ft in round 3 is pred_target_alan_v4_60 with test metrics:
# <style type="text/css">
# #T_e909d   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_e909d thead {
#   background-color: lightblue;
# }
# #T_e909d tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_e909d tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_e909d td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_e909d th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_e909d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e909d_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_e909d_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_e909d_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e909d_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_e909d_row0_col0" class="data row0 col0" >2.82%</td>
#       <td id="T_e909d_row0_col1" class="data row0 col1" >1.86%</td>
#       <td id="T_e909d_row0_col2" class="data row0 col2" >153.85%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:54:00]  Adding pred_target_alan_v4_60...
# <style type="text/css">
# #T_7ae31   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_7ae31 thead {
#   background-color: lightblue;
# }
# #T_7ae31 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_7ae31 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_7ae31 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_7ae31 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_7ae31_row0_col0, #T_7ae31_row1_col0, #T_7ae31_row2_col0, #T_7ae31_row3_col0 {
#   width: 10em;
# }
# #T_7ae31_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.1%, transparent 92.1%);
# }
# #T_7ae31_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 85.9%, transparent 85.9%);
# }
# #T_7ae31_row0_col3, #T_7ae31_row0_col5, #T_7ae31_row2_col1, #T_7ae31_row2_col2, #T_7ae31_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_7ae31_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.1%, transparent 87.1%);
# }
# #T_7ae31_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.7%, transparent 98.7%);
# }
# #T_7ae31_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.1%, transparent 94.1%);
# }
# #T_7ae31_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.8%, transparent 88.8%);
# }
# #T_7ae31_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.2%, transparent 97.2%);
# }
# #T_7ae31_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.5%, transparent 86.5%);
# }
# #T_7ae31_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.1%, transparent 93.1%);
# }
# #T_7ae31_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.5%, transparent 73.5%);
# }
# #T_7ae31_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 96.9%, transparent 96.9%);
# }
# #T_7ae31_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.3%, transparent 93.3%);
# }
# #T_7ae31_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.0%, transparent 94.0%);
# }
# #T_7ae31_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.8%, transparent 94.8%);
# }
# #T_7ae31_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.7%, transparent 86.7%);
# }
# </style>
# <table id="T_7ae31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ae31_level0_col0" class="col_heading level0 col0" >intercept</th>
#       <th id="T_7ae31_level0_col1" class="col_heading level0 col1" >cyrus_v4_20</th>
#       <th id="T_7ae31_level0_col2" class="col_heading level0 col2" >tyler_v4_20</th>
#       <th id="T_7ae31_level0_col3" class="col_heading level0 col3" >victor_v4_20</th>
#       <th id="T_7ae31_level0_col4" class="col_heading level0 col4" >waldo_v4_20</th>
#       <th id="T_7ae31_level0_col5" class="col_heading level0 col5" >alan_v4_60</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ae31_level0_row0" class="row_heading level0 row0" >coef_cv0</th>
#       <td id="T_7ae31_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_7ae31_row0_col1" class="data row0 col1" >21.53%</td>
#       <td id="T_7ae31_row0_col2" class="data row0 col2" >17.07%</td>
#       <td id="T_7ae31_row0_col3" class="data row0 col3" >21.12%</td>
#       <td id="T_7ae31_row0_col4" class="data row0 col4" >15.27%</td>
#       <td id="T_7ae31_row0_col5" class="data row0 col5" >25.04%</td>
#     </tr>
#     <tr>
#       <th id="T_7ae31_level0_row1" class="row_heading level0 row1" >coef_cv1</th>
#       <td id="T_7ae31_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_7ae31_row1_col1" class="data row1 col1" >24.89%</td>
#       <td id="T_7ae31_row1_col2" class="data row1 col2" >20.93%</td>
#       <td id="T_7ae31_row1_col3" class="data row1 col3" >16.38%</td>
#       <td id="T_7ae31_row1_col4" class="data row1 col4" >19.39%</td>
#       <td id="T_7ae31_row1_col5" class="data row1 col5" >18.25%</td>
#     </tr>
#     <tr>
#       <th id="T_7ae31_level0_row2" class="row_heading level0 row2" >coef_cv2</th>
#       <td id="T_7ae31_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_7ae31_row2_col1" class="data row2 col1" >25.56%</td>
#       <td id="T_7ae31_row2_col2" class="data row2 col2" >23.75%</td>
#       <td id="T_7ae31_row2_col3" class="data row2 col3" >18.22%</td>
#       <td id="T_7ae31_row2_col4" class="data row2 col4" >20.56%</td>
#       <td id="T_7ae31_row2_col5" class="data row2 col5" >11.77%</td>
#     </tr>
#     <tr>
#       <th id="T_7ae31_level0_row3" class="row_heading level0 row3" >avg</th>
#       <td id="T_7ae31_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_7ae31_row3_col1" class="data row3 col1" >23.99%</td>
#       <td id="T_7ae31_row3_col2" class="data row3 col2" >20.58%</td>
#       <td id="T_7ae31_row3_col3" class="data row3 col3" >18.58%</td>
#       <td id="T_7ae31_row3_col4" class="data row3 col4" >18.41%</td>
#       <td id="T_7ae31_row3_col5" class="data row3 col5" >18.35%</td>
#     </tr>
#   </tbody>
# </table>
# Trying feature:   0%|          | 0/31 [00:00<?, ?it/s]
# [2023-04-28 21:54:24]  Best ft in round 4 is pred_target_jerome_v4_60 with validation metrics:
# <style type="text/css">
# #T_6cbf9   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_6cbf9 thead {
#   background-color: lightblue;
# }
# #T_6cbf9 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_6cbf9 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_6cbf9 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_6cbf9 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_6cbf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cbf9_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_6cbf9_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_6cbf9_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cbf9_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_6cbf9_row0_col0" class="data row0 col0" >3.18%</td>
#       <td id="T_6cbf9_row0_col1" class="data row0 col1" >1.68%</td>
#       <td id="T_6cbf9_row0_col2" class="data row0 col2" >196.48%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:54:27]  Best ft in round 4 is pred_target_jerome_v4_60 with test metrics:
# <style type="text/css">
# #T_f9016   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_f9016 thead {
#   background-color: lightblue;
# }
# #T_f9016 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_f9016 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_f9016 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_f9016 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_f9016">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9016_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_f9016_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_f9016_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9016_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_f9016_row0_col0" class="data row0 col0" >2.82%</td>
#       <td id="T_f9016_row0_col1" class="data row0 col1" >1.85%</td>
#       <td id="T_f9016_row0_col2" class="data row0 col2" >154.44%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:54:27]  Adding pred_target_jerome_v4_60...
# <style type="text/css">
# #T_f61fe   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_f61fe thead {
#   background-color: lightblue;
# }
# #T_f61fe tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_f61fe tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_f61fe td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_f61fe th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_f61fe_row0_col0, #T_f61fe_row1_col0, #T_f61fe_row2_col0, #T_f61fe_row3_col0 {
#   width: 10em;
# }
# #T_f61fe_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.0%, transparent 90.0%);
# }
# #T_f61fe_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 83.3%, transparent 83.3%);
# }
# #T_f61fe_row0_col3, #T_f61fe_row0_col5, #T_f61fe_row0_col6, #T_f61fe_row2_col1, #T_f61fe_row2_col2, #T_f61fe_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_f61fe_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 83.5%, transparent 83.5%);
# }
# #T_f61fe_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.6%, transparent 98.6%);
# }
# #T_f61fe_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.1%, transparent 94.1%);
# }
# #T_f61fe_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 91.0%, transparent 91.0%);
# }
# #T_f61fe_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.1%, transparent 97.1%);
# }
# #T_f61fe_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.6%, #d65f5f 36.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_f61fe_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.7%, transparent 88.7%);
# }
# #T_f61fe_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 95.7%, transparent 95.7%);
# }
# #T_f61fe_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.2%, #d65f5f 32.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_f61fe_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 75.7%, transparent 75.7%);
# }
# #T_f61fe_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 96.2%, transparent 96.2%);
# }
# #T_f61fe_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.5%, transparent 92.5%);
# }
# #T_f61fe_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 95.6%, transparent 95.6%);
# }
# #T_f61fe_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.5%, transparent 93.5%);
# }
# #T_f61fe_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 56.3%, transparent 56.3%);
# }
# #T_f61fe_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.1%, transparent 88.1%);
# }
# </style>
# <table id="T_f61fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f61fe_level0_col0" class="col_heading level0 col0" >intercept</th>
#       <th id="T_f61fe_level0_col1" class="col_heading level0 col1" >cyrus_v4_20</th>
#       <th id="T_f61fe_level0_col2" class="col_heading level0 col2" >tyler_v4_20</th>
#       <th id="T_f61fe_level0_col3" class="col_heading level0 col3" >victor_v4_20</th>
#       <th id="T_f61fe_level0_col4" class="col_heading level0 col4" >waldo_v4_20</th>
#       <th id="T_f61fe_level0_col5" class="col_heading level0 col5" >jerome_v4_60</th>
#       <th id="T_f61fe_level0_col6" class="col_heading level0 col6" >alan_v4_60</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f61fe_level0_row0" class="row_heading level0 row0" >coef_cv0</th>
#       <td id="T_f61fe_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_f61fe_row0_col1" class="data row0 col1" >20.67%</td>
#       <td id="T_f61fe_row0_col2" class="data row0 col2" >16.04%</td>
#       <td id="T_f61fe_row0_col3" class="data row0 col3" >20.24%</td>
#       <td id="T_f61fe_row0_col4" class="data row0 col4" >14.02%</td>
#       <td id="T_f61fe_row0_col5" class="data row0 col5" >5.11%</td>
#       <td id="T_f61fe_row0_col6" class="data row0 col6" >23.97%</td>
#     </tr>
#     <tr>
#       <th id="T_f61fe_level0_row1" class="row_heading level0 row1" >coef_cv1</th>
#       <td id="T_f61fe_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_f61fe_row1_col1" class="data row1 col1" >25.09%</td>
#       <td id="T_f61fe_row1_col2" class="data row1 col2" >21.23%</td>
#       <td id="T_f61fe_row1_col3" class="data row1 col3" >16.61%</td>
#       <td id="T_f61fe_row1_col4" class="data row1 col4" >19.73%</td>
#       <td id="T_f61fe_row1_col5" class="data row1 col5" >-1.37%</td>
#       <td id="T_f61fe_row1_col6" class="data row1 col6" >18.55%</td>
#     </tr>
#     <tr>
#       <th id="T_f61fe_level0_row2" class="row_heading level0 row2" >coef_cv2</th>
#       <td id="T_f61fe_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_f61fe_row2_col1" class="data row2 col1" >25.84%</td>
#       <td id="T_f61fe_row2_col2" class="data row2 col2" >24.08%</td>
#       <td id="T_f61fe_row2_col3" class="data row2 col3" >18.50%</td>
#       <td id="T_f61fe_row2_col4" class="data row2 col4" >20.96%</td>
#       <td id="T_f61fe_row2_col5" class="data row2 col5" >-1.82%</td>
#       <td id="T_f61fe_row2_col6" class="data row2 col6" >12.30%</td>
#     </tr>
#     <tr>
#       <th id="T_f61fe_level0_row3" class="row_heading level0 row3" >avg</th>
#       <td id="T_f61fe_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_f61fe_row3_col1" class="data row3 col1" >23.87%</td>
#       <td id="T_f61fe_row3_col2" class="data row3 col2" >20.45%</td>
#       <td id="T_f61fe_row3_col3" class="data row3 col3" >18.45%</td>
#       <td id="T_f61fe_row3_col4" class="data row3 col4" >18.24%</td>
#       <td id="T_f61fe_row3_col5" class="data row3 col5" >0.64%</td>
#       <td id="T_f61fe_row3_col6" class="data row3 col6" >18.27%</td>
#     </tr>
#   </tbody>
# </table>
# Trying feature:   0%|          | 0/30 [00:00<?, ?it/s]
# [2023-04-28 21:54:50]  Best ft in round 5 is pred_target_william_v4_20 with validation metrics:
# <style type="text/css">
# #T_b62fc   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_b62fc thead {
#   background-color: lightblue;
# }
# #T_b62fc tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_b62fc tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_b62fc td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_b62fc th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_b62fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b62fc_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_b62fc_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_b62fc_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b62fc_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_b62fc_row0_col0" class="data row0 col0" >3.19%</td>
#       <td id="T_b62fc_row0_col1" class="data row0 col1" >1.67%</td>
#       <td id="T_b62fc_row0_col2" class="data row0 col2" >198.08%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:54:54]  Best ft in round 5 is pred_target_william_v4_20 with test metrics:
# <style type="text/css">
# #T_5a9f6   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_5a9f6 thead {
#   background-color: lightblue;
# }
# #T_5a9f6 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_5a9f6 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_5a9f6 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_5a9f6 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_5a9f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a9f6_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_5a9f6_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_5a9f6_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a9f6_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_5a9f6_row0_col0" class="data row0 col0" >2.80%</td>
#       <td id="T_5a9f6_row0_col1" class="data row0 col1" >1.86%</td>
#       <td id="T_5a9f6_row0_col2" class="data row0 col2" >151.86%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:54:54]  Adding pred_target_william_v4_20...
# <style type="text/css">
# #T_5e186   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_5e186 thead {
#   background-color: lightblue;
# }
# #T_5e186 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_5e186 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_5e186 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_5e186 th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_5e186_row0_col0, #T_5e186_row1_col0, #T_5e186_row2_col0, #T_5e186_row3_col0 {
#   width: 10em;
# }
# #T_5e186_row0_col1, #T_5e186_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.0%, transparent 92.0%);
# }
# #T_5e186_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 84.2%, transparent 84.2%);
# }
# #T_5e186_row0_col3, #T_5e186_row0_col6, #T_5e186_row1_col1, #T_5e186_row2_col1, #T_5e186_row2_col2, #T_5e186_row2_col4, #T_5e186_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_5e186_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 83.7%, transparent 83.7%);
# }
# #T_5e186_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.1%, transparent 73.1%);
# }
# #T_5e186_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 80.4%, transparent 80.4%);
# }
# #T_5e186_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 95.0%, transparent 95.0%);
# }
# #T_5e186_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.4%, transparent 87.4%);
# }
# #T_5e186_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.4%, transparent 97.4%);
# }
# #T_5e186_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.7%, #d65f5f 12.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_5e186_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.1%, transparent 87.1%);
# }
# #T_5e186_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.1%, transparent 90.1%);
# }
# #T_5e186_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_5e186_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 74.6%, transparent 74.6%);
# }
# #T_5e186_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 97.3%, transparent 97.3%);
# }
# #T_5e186_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.1%, transparent 93.1%);
# }
# #T_5e186_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.5%, transparent 92.5%);
# }
# #T_5e186_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.7%, transparent 93.7%);
# }
# #T_5e186_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.6%, #d65f5f 28.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_5e186_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.2%, transparent 87.2%);
# }
# #T_5e186_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.8%, transparent 90.8%);
# }
# </style>
# <table id="T_5e186">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e186_level0_col0" class="col_heading level0 col0" >intercept</th>
#       <th id="T_5e186_level0_col1" class="col_heading level0 col1" >cyrus_v4_20</th>
#       <th id="T_5e186_level0_col2" class="col_heading level0 col2" >tyler_v4_20</th>
#       <th id="T_5e186_level0_col3" class="col_heading level0 col3" >victor_v4_20</th>
#       <th id="T_5e186_level0_col4" class="col_heading level0 col4" >waldo_v4_20</th>
#       <th id="T_5e186_level0_col5" class="col_heading level0 col5" >jerome_v4_60</th>
#       <th id="T_5e186_level0_col6" class="col_heading level0 col6" >alan_v4_60</th>
#       <th id="T_5e186_level0_col7" class="col_heading level0 col7" >william_v4_20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e186_level0_row0" class="row_heading level0 row0" >coef_cv0</th>
#       <td id="T_5e186_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_5e186_row0_col1" class="data row0 col1" >18.49%</td>
#       <td id="T_5e186_row0_col2" class="data row0 col2" >14.14%</td>
#       <td id="T_5e186_row0_col3" class="data row0 col3" >17.94%</td>
#       <td id="T_5e186_row0_col4" class="data row0 col4" >12.00%</td>
#       <td id="T_5e186_row0_col5" class="data row0 col5" >2.83%</td>
#       <td id="T_5e186_row0_col6" class="data row0 col6" >22.51%</td>
#       <td id="T_5e186_row0_col7" class="data row0 col7" >12.06%</td>
#     </tr>
#     <tr>
#       <th id="T_5e186_level0_row1" class="row_heading level0 row1" >coef_cv1</th>
#       <td id="T_5e186_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_5e186_row1_col1" class="data row1 col1" >22.01%</td>
#       <td id="T_5e186_row1_col2" class="data row1 col2" >18.60%</td>
#       <td id="T_5e186_row1_col3" class="data row1 col3" >13.42%</td>
#       <td id="T_5e186_row1_col4" class="data row1 col4" >16.88%</td>
#       <td id="T_5e186_row1_col5" class="data row1 col5" >-4.57%</td>
#       <td id="T_5e186_row1_col6" class="data row1 col6" >16.70%</td>
#       <td id="T_5e186_row1_col7" class="data row1 col7" >16.68%</td>
#     </tr>
#     <tr>
#       <th id="T_5e186_level0_row2" class="row_heading level0 row2" >coef_cv2</th>
#       <td id="T_5e186_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_5e186_row2_col1" class="data row2 col1" >22.01%</td>
#       <td id="T_5e186_row2_col2" class="data row2 col2" >20.64%</td>
#       <td id="T_5e186_row2_col3" class="data row2 col3" >14.38%</td>
#       <td id="T_5e186_row2_col4" class="data row2 col4" >17.79%</td>
#       <td id="T_5e186_row2_col5" class="data row2 col5" >-6.13%</td>
#       <td id="T_5e186_row2_col6" class="data row2 col6" >11.09%</td>
#       <td id="T_5e186_row2_col7" class="data row2 col7" >19.86%</td>
#     </tr>
#     <tr>
#       <th id="T_5e186_level0_row3" class="row_heading level0 row3" >avg</th>
#       <td id="T_5e186_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_5e186_row3_col1" class="data row3 col1" >20.84%</td>
#       <td id="T_5e186_row3_col2" class="data row3 col2" >17.79%</td>
#       <td id="T_5e186_row3_col3" class="data row3 col3" >15.25%</td>
#       <td id="T_5e186_row3_col4" class="data row3 col4" >15.56%</td>
#       <td id="T_5e186_row3_col5" class="data row3 col5" >-2.62%</td>
#       <td id="T_5e186_row3_col6" class="data row3 col6" >16.77%</td>
#       <td id="T_5e186_row3_col7" class="data row3 col7" >16.20%</td>
#     </tr>
#   </tbody>
# </table>
# Trying feature:   0%|          | 0/29 [00:00<?, ?it/s]
# [2023-04-28 21:55:16]  Best ft in round 6 is pred_target_caroline_v4_20 with validation metrics:
# <style type="text/css">
# #T_78b20   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_78b20 thead {
#   background-color: lightblue;
# }
# #T_78b20 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_78b20 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_78b20 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_78b20 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_78b20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78b20_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_78b20_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_78b20_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78b20_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_78b20_row0_col0" class="data row0 col0" >3.20%</td>
#       <td id="T_78b20_row0_col1" class="data row0 col1" >1.68%</td>
#       <td id="T_78b20_row0_col2" class="data row0 col2" >198.35%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:55:19]  Best ft in round 6 is pred_target_caroline_v4_20 with test metrics:
# <style type="text/css">
# #T_0d0e2   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_0d0e2 thead {
#   background-color: lightblue;
# }
# #T_0d0e2 tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_0d0e2 tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_0d0e2 td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_0d0e2 th {
#   font-size: 100%;
#   text-align: center;
# }
# </style>
# <table id="T_0d0e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d0e2_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_0d0e2_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_0d0e2_level0_col2" class="col_heading level0 col2" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d0e2_level0_row0" class="row_heading level0 row0" >cv_mean</th>
#       <td id="T_0d0e2_row0_col0" class="data row0 col0" >2.81%</td>
#       <td id="T_0d0e2_row0_col1" class="data row0 col1" >1.85%</td>
#       <td id="T_0d0e2_row0_col2" class="data row0 col2" >153.05%</td>
#     </tr>
#   </tbody>
# </table>
# [2023-04-28 21:55:19]  Adding pred_target_caroline_v4_20...
# <style type="text/css">
# #T_fb55e   {
#   margin: 0;
#   font-family: "Helvetica", "Arial", sans-serif;
#   border-collapse: collapse;
#   border: none;
#   border: 2px solid #ccf;
# }
# #T_fb55e thead {
#   background-color: lightblue;
# }
# #T_fb55e tbody tr:nth-child(even) {
#   background-color: #fff;
# }
# #T_fb55e tbody tr:nth-child(odd) {
#   background-color: #eee;
# }
# #T_fb55e td {
#   padding: .5em;
#   background-position-x: initial;
#   background-position-y: initial;
# }
# #T_fb55e th {
#   font-size: 100%;
#   text-align: center;
# }
# #T_fb55e_row0_col0, #T_fb55e_row1_col0, #T_fb55e_row2_col0, #T_fb55e_row3_col0 {
#   width: 10em;
# }
# #T_fb55e_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.0%, transparent 92.0%);
# }
# #T_fb55e_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 93.0%, transparent 93.0%);
# }
# #T_fb55e_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 81.8%, transparent 81.8%);
# }
# #T_fb55e_row0_col4, #T_fb55e_row0_col7, #T_fb55e_row1_col2, #T_fb55e_row2_col1, #T_fb55e_row2_col3, #T_fb55e_row2_col5, #T_fb55e_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_fb55e_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 81.3%, transparent 81.3%);
# }
# #T_fb55e_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 65.1%, transparent 65.1%);
# }
# #T_fb55e_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 77.3%, transparent 77.3%);
# }
# #T_fb55e_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 98.7%, transparent 98.7%);
# }
# #T_fb55e_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.8%, transparent 92.8%);
# }
# #T_fb55e_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 83.6%, transparent 83.6%);
# }
# #T_fb55e_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 95.8%, transparent 95.8%);
# }
# #T_fb55e_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 10.0%, #d65f5f 10.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_fb55e_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 85.9%, transparent 85.9%);
# }
# #T_fb55e_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 89.1%, transparent 89.1%);
# }
# #T_fb55e_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.5%, transparent 90.5%);
# }
# #T_fb55e_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.6%, transparent 88.6%);
# }
# #T_fb55e_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_fb55e_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.5%, transparent 73.5%);
# }
# #T_fb55e_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 96.9%, transparent 96.9%);
# }
# #T_fb55e_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 94.5%, transparent 94.5%);
# }
# #T_fb55e_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 91.5%, transparent 91.5%);
# }
# #T_fb55e_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 90.7%, transparent 90.7%);
# }
# #T_fb55e_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 92.4%, transparent 92.4%);
# }
# #T_fb55e_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_fb55e_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.5%, transparent 86.5%);
# }
# #T_fb55e_row3_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 88.8%, transparent 88.8%);
# }
# </style>
# <table id="T_fb55e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb55e_level0_col0" class="col_heading level0 col0" >intercept</th>
#       <th id="T_fb55e_level0_col1" class="col_heading level0 col1" >cyrus_v4_20</th>
#       <th id="T_fb55e_level0_col2" class="col_heading level0 col2" >caroline_v4_20</th>
#       <th id="T_fb55e_level0_col3" class="col_heading level0 col3" >tyler_v4_20</th>
#       <th id="T_fb55e_level0_col4" class="col_heading level0 col4" >victor_v4_20</th>
#       <th id="T_fb55e_level0_col5" class="col_heading level0 col5" >waldo_v4_20</th>
#       <th id="T_fb55e_level0_col6" class="col_heading level0 col6" >jerome_v4_60</th>
#       <th id="T_fb55e_level0_col7" class="col_heading level0 col7" >alan_v4_60</th>
#       <th id="T_fb55e_level0_col8" class="col_heading level0 col8" >william_v4_20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb55e_level0_row0" class="row_heading level0 row0" >coef_cv0</th>
#       <td id="T_fb55e_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_fb55e_row0_col1" class="data row0 col1" >15.09%</td>
#       <td id="T_fb55e_row0_col2" class="data row0 col2" >15.74%</td>
#       <td id="T_fb55e_row0_col3" class="data row0 col3" >11.92%</td>
#       <td id="T_fb55e_row0_col4" class="data row0 col4" >15.37%</td>
#       <td id="T_fb55e_row0_col5" class="data row0 col5" >9.46%</td>
#       <td id="T_fb55e_row0_col6" class="data row0 col6" >1.95%</td>
#       <td id="T_fb55e_row0_col7" class="data row0 col7" >20.69%</td>
#       <td id="T_fb55e_row0_col8" class="data row0 col8" >9.79%</td>
#     </tr>
#     <tr>
#       <th id="T_fb55e_level0_row1" class="row_heading level0 row1" >coef_cv1</th>
#       <td id="T_fb55e_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_fb55e_row1_col1" class="data row1 col1" >17.52%</td>
#       <td id="T_fb55e_row1_col2" class="data row1 col2" >18.30%</td>
#       <td id="T_fb55e_row1_col3" class="data row1 col3" >16.05%</td>
#       <td id="T_fb55e_row1_col4" class="data row1 col4" >10.34%</td>
#       <td id="T_fb55e_row1_col5" class="data row1 col5" >13.82%</td>
#       <td id="T_fb55e_row1_col6" class="data row1 col6" >-5.18%</td>
#       <td id="T_fb55e_row1_col7" class="data row1 col7" >14.87%</td>
#       <td id="T_fb55e_row1_col8" class="data row1 col8" >14.03%</td>
#     </tr>
#     <tr>
#       <th id="T_fb55e_level0_row2" class="row_heading level0 row2" >coef_cv2</th>
#       <td id="T_fb55e_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_fb55e_row2_col1" class="data row2 col1" >17.98%</td>
#       <td id="T_fb55e_row2_col2" class="data row2 col2" >14.82%</td>
#       <td id="T_fb55e_row2_col3" class="data row2 col3" >18.74%</td>
#       <td id="T_fb55e_row2_col4" class="data row2 col4" >11.85%</td>
#       <td id="T_fb55e_row2_col5" class="data row2 col5" >15.09%</td>
#       <td id="T_fb55e_row2_col6" class="data row2 col6" >-6.47%</td>
#       <td id="T_fb55e_row2_col7" class="data row2 col7" >9.73%</td>
#       <td id="T_fb55e_row2_col8" class="data row2 col8" >17.95%</td>
#     </tr>
#     <tr>
#       <th id="T_fb55e_level0_row3" class="row_heading level0 row3" >avg</th>
#       <td id="T_fb55e_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_fb55e_row3_col1" class="data row3 col1" >16.86%</td>
#       <td id="T_fb55e_row3_col2" class="data row3 col2" >16.29%</td>
#       <td id="T_fb55e_row3_col3" class="data row3 col3" >15.57%</td>
#       <td id="T_fb55e_row3_col4" class="data row3 col4" >12.52%</td>
#       <td id="T_fb55e_row3_col5" class="data row3 col5" >12.79%</td>
#       <td id
