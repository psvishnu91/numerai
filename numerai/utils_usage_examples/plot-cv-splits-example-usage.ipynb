# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))

import matplotlib.pyplot as plt
import sys, os
sys.path.append("..")
import utils as ut
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>

# %%
cv_splits = [
    # cv 0
    {
        # label: era range
        "train": (1, 795),
        #"validation": (721, 900),
        "test": (820, 1059),
    },
    # cv 1
    {
        "train": (1, 533),
        #"validation": (421, 600),
        "test": (556, 795),
    },
    # cv 2
    {
        "train": (1, 269),
        #"validation": (221, 401),
        "test": (292, 531),
    },
#     # cv 3
#     {
#         "train": (1, 200),
#         "validation": (221, 401),
#         "test": (421, 601),
#     },
#     # cv 4
#     {
#         "train": (1, 200),
#         "validation": (221, 401),
#         "test": (421, 601),
#     },
]

# %%
_, ax = plt.subplots(figsize=(10,5))
ut.plot_cv_split(
    cv_splits=cv_splits,
    era_col=ut.ERA_COL,
    linewidth=9,
    always_show_bin_ends=True,
    bin_end_offset=50,
    title="Walk forward Cross-Validation Splits",
    ax=ax,
);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 _, ax = plt.subplots(figsize=(10,5))
# ----> 2 ut.plot_cv_split(
#       3     cv_splits=cv_splits,
#       4     era_col=ut.ERA_COL,
#       5     linewidth=9,
#       6     always_show_bin_ends=True,
#       7     bin_end_offset=50,
#       8     title="Walk forward Cross-Validation Splits",
#       9     ax=ax,
#      10 );
#
# File ~/pg/numerai-visp/numerai/utils_usage_examples/../utils.py:1422, in plot_cv_split(cv_splits, era_col, linewidth, always_show_bin_ends, bin_end_offset, title, annot_fontsize, title_fontsize, ax)
#    1420 yticklabels = list(range(n_splits))
#    1421 x_range = xmax - xmin
# -> 1422 ax.set(
#    1423     yticks=np.arange(n_splits) + 0.5,
#    1424     yticklabels=yticklabels,
#    1425     xlabel=era_col,
#    1426     ylabel="CV iteration",
#    1427     ylim=[n_splits + 0.2, -0.2],
#    1428     xlim=[xmin - x_range * 0.1, xmax + x_range * 0.1],
#    1429     title=title,
#    1430     title_fontsize=title_fontsize,
#    1431 )
#    1432 return ax
#
# File ~/venvs/venv3/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/venvs/venv3/lib/python3.10/site-packages/matplotlib/artist.py:1231, in Artist.set(self, **kwargs)
#    1227 def set(self, **kwargs):
#    1228     # docstring and signature are auto-generated via
#    1229     # Artist._update_set_signature_and_docstring() at the end of the
#    1230     # module.
# -> 1231     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/venvs/venv3/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/venvs/venv3/lib/python3.10/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Axes.set() got an unexpected keyword argument 'title_fontsize'
